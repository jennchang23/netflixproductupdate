# %%
import pandas as pd

# %%
netflix = pd.read_csv("data/netflix_titles.csv")
netflix.head()
# pd.read_csv("../data/rotten_tomatoes_movies.csv")
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
# 1  80117401  Movie               Jandino: Whatever it Takes
# 2  80125979  Movie                             #realityhigh
# 3  70304989  Movie                                 Automata
# 4  80164077  Movie       Fabrizio Copano: Solo pienso en mi
#
#                           director  \
# 0         Richard Finn, Tim Maltby
# 1                              NaN
# 2                 Fernando Lebrija
# 3                      Gabe Ibáñez
# 4  Rodrigo Toro, Francisco Schultz
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Nesta Cooper, Kate Walsh, John Michael Higgins...
# 3  Antonio Banderas, Dylan McDermott, Melanie Gri...
# 4                                    Fabrizio Copano
#
# ...

# %%
netflix["title_release_year"]=0
netflix.head()

# create column for unique ID (title & release year) in netflix dataframe
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
# 1  80117401  Movie               Jandino: Whatever it Takes
# 2  80125979  Movie                             #realityhigh
# 3  70304989  Movie                                 Automata
# 4  80164077  Movie       Fabrizio Copano: Solo pienso en mi
#
#                           director  \
# 0         Richard Finn, Tim Maltby
# 1                              NaN
# 2                 Fernando Lebrija
# 3                      Gabe Ibáñez
# 4  Rodrigo Toro, Francisco Schultz
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Nesta Cooper, Kate Walsh, John Michael Higgins...
# 3  Antonio Banderas, Dylan McDermott, Melanie Gri...
# 4                                    Fabrizio Copano
#
# ...

# %%
# netflix["title_release_year"]=netflix["title"]+ str(netflix["release_year"])
# netflix.head()
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
# 1  80117401  Movie               Jandino: Whatever it Takes
# 2  80125979  Movie                             #realityhigh
# 3  70304989  Movie                                 Automata
# 4  80164077  Movie       Fabrizio Copano: Solo pienso en mi
#
#                           director  \
# 0         Richard Finn, Tim Maltby
# 1                              NaN
# 2                 Fernando Lebrija
# 3                      Gabe Ibáñez
# 4  Rodrigo Toro, Francisco Schultz
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Nesta Cooper, Kate Walsh, John Michael Higgins...
# 3  Antonio Banderas, Dylan McDermott, Melanie Gri...
# 4                                    Fabrizio Copano
#
# ...

# %%
# netflix["title"]+ str(netflix["release_year"])

# %%
netflix["title_release_year"] = netflix["title"]+ "_" + netflix["release_year"].astype(str)
# fill in title_release_year column with calculated key values

# %%
netflix.head()
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
# 1  80117401  Movie               Jandino: Whatever it Takes
# 2  80125979  Movie                             #realityhigh
# 3  70304989  Movie                                 Automata
# 4  80164077  Movie       Fabrizio Copano: Solo pienso en mi
#
#                           director  \
# 0         Richard Finn, Tim Maltby
# 1                              NaN
# 2                 Fernando Lebrija
# 3                      Gabe Ibáñez
# 4  Rodrigo Toro, Francisco Schultz
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Nesta Cooper, Kate Walsh, John Michael Higgins...
# 3  Antonio Banderas, Dylan McDermott, Melanie Gri...
# 4                                    Fabrizio Copano
#
# ...

# %%
rotten_tomatoes = pd.read_csv("data/rotten_tomatoes_movies.csv")
rotten_tomatoes.head()

# read rotten tomatoes data
# Out:
#                      rotten_tomatoes_link  \
# 0                              /m/0814255
# 1                              /m/0878835
# 2                                   /m/10
# 3                 /m/1000013-12_angry_men
# 4  /m/1000079-20000_leagues_under_the_sea
#
#                                          movie_title  \
# 0  Percy Jackson & the Olympians: The Lightning T...
# 1                                        Please Give
# 2                                                 10
# 3                    12 Angry Men (Twelve Angry Men)
# 4                       20,000 Leagues Under The Sea
#
#                                           movie_info  \
# 0  A teenager discovers he's the descendant of a ...
# 1  Kate has a lot on her mind. There's the ethics...
# 2  Blake Edwards' 10 stars Dudley Moore as George...
# 3  A Puerto Rican youth is on trial for murder, a...
# 4  This 1954 Disney version of Jules Verne's 20,0...
#
#                                    critics_consensus  \
# ...

# %%
rotten_tomatoes["release_year"]=0
rotten_tomatoes["title_release_year"]=0
rotten_tomatoes.head()

# create two columns for release year and unique ID (title & release year) in rotten tomatoes dataframe

# %%
rotten_tomatoes["release_year"] = rotten_tomatoes['in_theaters_date'].str[:4]
# parse out in-theater date to have release year in separate column

# %%
rotten_tomatoes["title_release_year"] = rotten_tomatoes["movie_title"]+ "_" + rotten_tomatoes["release_year"].astype(str)
# fill in title_release_year column with calculated key values

# %%
master_df = pd.merge(netflix, rotten_tomatoes, "title_release_year")
